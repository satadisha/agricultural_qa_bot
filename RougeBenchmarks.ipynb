# %%
# !pip install -q nltk evaluate rouge-score bert_score transformers accelerate

# %%
# Imports
from transformers import AutoModelForCausalLM, AutoTokenizer
from rouge_score import rouge_scorer
from tqdm import tqdm
import pandas as pd
from collections import defaultdict
import json
import nltk
import torch
from evaluate import load as load_metric

# %%
# !pip uninstall bitsandbytes

# %%
# !pip install -U bitsandbytes

# %%
import bitsandbytes

# %%
nltk.download('wordnet')
nltk.download('punkt')

# %%
from huggingface_hub import login
login()

# %%
# torch.cuda.empty_cache()

model_a = AutoModelForCausalLM.from_pretrained(
    "MarsGray/Gemma-2b-it-merged-1.0",
    device_map="auto",
    torch_dtype=torch.float16
)
tokenizer_a = AutoTokenizer.from_pretrained("MarsGray/Gemma-2b-it-merged-1.0")

model_b = AutoModelForCausalLM.from_pretrained(
    "MarsGray/Phi-4-mini-instruct-merged-1.2",
    device_map="auto",
    torch_dtype=torch.float16
)
tokenizer_b = AutoTokenizer.from_pretrained("MarsGray/Phi-4-mini-instruct-merged-1.2")

model_c = AutoModelForCausalLM.from_pretrained(
    "GRojas98/qa-llama-finetuned",
    device_map="auto",
    torch_dtype=torch.float16
)
tokenizer_c = AutoTokenizer.from_pretrained("GRojas98/qa-llama-finetuned")
# Out:
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/9.19M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
for tokenizer in [tokenizer_a, tokenizer_b, tokenizer_c]:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = "right"

# %%
# Define generation and evaluation functions
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
bleu_metric = load_metric("bleu")
meteor_metric = load_metric("meteor")
from bert_score import score as bert_score


def generate_response(model, tokenizer, prompt, max_new_tokens=256):
  """
  Generate a response from the model and tokenizer based on the prompt

  Args:
    model: The language model to generate response.
    tokenizer: The tokenizer for the corresponding model.
    prompt: The input instruction/question
    max_new_tokens: Max number of new tokens for generation

  Returns:
    str: The generated response
  """
  inputs = tokenizer(prompt, return_tensors="pt", padding=True, truncation=True).to(model.device)
  outputs = model.generate(**inputs, max_new_tokens=max_new_tokens)
  return tokenizer.decode(outputs[0], skip_special_tokens=True)

def evaluate_model(model, tokenizer, dataset):
  """
  Evaluate the model on a dataset by generating responses and computing ROUGE scores.

  Args:
    model: The language model to evaluate.
    tokenizer: The tokenizer for the corresponding model.
    dataset: A list of dictionaries with "instruction" and "response" keys.

  Returns:
    tuple: A tuple containing:
        - list: A list of ROUGE score dictionaries for each example
        - list: A list of model predictions
        - list: A list of reference responses
  """
  scores = []
  predictions = []
  references = []
  for sample in tqdm(dataset):
    prompt = sample["instruction"]
    reference = sample["response"]

    prediction = generate_response(model, tokenizer, prompt)
    # prediction = prediction.strip().split("### Response:")[-1].strip()

    result = scorer.score(reference, prediction)
    scores.append(result)
    predictions.append(prediction)
    references.append(reference)
  return scores, predictions, references

def average_rouge_scores(scores):
  """
  Compute averae ROUGE scores from a list of score dictionaries.

  Args:
    scores (list): List of ROUGE score dictionaries.

  Return:
    dict: Dictionary of averaged ROUGE scores (f-measure).
  """
  avg_scores = defaultdict(float)
  for score in scores:
    for key in score:
      avg_scores[key] += score[key].fmeasure
  for key in avg_scores:
    avg_scores[key] /= len(scores)
  return dict(avg_scores)

def evaluate_with_bertscore(predictions, references, lang='en'):
    """
    Compute BERTScore between predicted and reference responses.

    Args:
        predictions (list of str): Model-generated responses.
        references (list of str): Ground truth answers.
        lang (str): Language code (default: 'en').

    Returns:
        dict: Average BERTScore precision, recall, and F1.
    """
    P, R, F1 = bert_score(predictions, references, lang=lang)
    return {
        "bert_precision": P.mean().item(),
        "bert_recall": R.mean().item(),
        "bert_f1": F1.mean().item()
    }

def compute_bleu_meteor(predictions, references):
    """
    Compute BLEU and METEOR scores.

    Args:
        predictions (list): List of generated responses.
        references (list): List of reference responses.

    Returns:
        dict: Dictionary with 'bleu' and 'meteor' scores.
    """
    bleu_score = bleu_metric.compute(
        predictions=predictions,
        references=[[ref] for ref in references]
    )["bleu"]

    meteor_score = meteor_metric.compute(
        predictions=predictions,
        references=references
    )["meteor"]

    return {
        "bleu": bleu_score,
        "meteor": meteor_score
    }
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Load Evaluation Dataset from QA_fintuned.jsonl
file_path = "/content/gdrive/MyDrive/QA_finetuned.jsonl"
eval_set = []
with open(file_path, "r", encoding="utf-8") as f:
  for i, line in enumerate(f):
    if i >= 430:
      try:
        sample = json.loads(line.strip())
        if "instruction" in sample and "response" in sample:
          eval_set.append(sample)
      except json.JSONDecodeError:
        continue
print(f"Loaded {len(eval_set)} evaluation sample.")
# Out:
# Loaded 108 evaluation sample.

# %%
# Run Evaluations
scores_a, preds_a, refs_a = evaluate_model(model_a, tokenizer_a, eval_set)
scores_b, preds_b, refs_b = evaluate_model(model_b, tokenizer_b, eval_set)
scores_c, preds_c, refs_c = evaluate_model(model_c, tokenizer_c, eval_set)

avg_a = average_rouge_scores(scores_a)
avg_b = average_rouge_scores(scores_b)
avg_c = average_rouge_scores(scores_c)

bert_a = evaluate_with_bertscore(preds_a, refs_a)
bert_b = evaluate_with_bertscore(preds_b, refs_b)
bert_c = evaluate_with_bertscore(preds_c, refs_c)
# Out:
# 100%|██████████| 108/108 [04:22<00:00,  2.43s/it]
# 100%|██████████| 108/108 [32:04<00:00, 17.82s/it]
#   0%|          | 0/108 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 1/108 [00:12<21:30, 12.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 2/108 [00:23<20:49, 11.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 3/108 [00:35<20:29, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 4/108 [00:45<19:34, 11.29s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 5/108 [00:53<16:57,  9.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 6/108 [01:05<17:52, 10.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 7/108 [01:16<18:18, 10.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 8/108 [01:28<18:32, 11.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 9/108 [01:39<18:34, 11.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 10/108 [01:42<14:00,  8.57s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 11/108 [01:54<15:21,  9.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 12/108 [02:05<16:14, 10.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 13/108 [02:14<15:36,  9.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 14/108 [02:26<16:11, 10.33s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 15/108 [02:33<14:41,  9.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 16/108 [02:45<15:27, 10.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 17/108 [02:51<13:44,  9.06s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 18/108 [03:03<14:43,  9.82s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 19/108 [03:08<12:36,  8.51s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 20/108 [03:20<13:51,  9.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 21/108 [03:32<14:35, 10.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 22/108 [03:43<15:02, 10.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 23/108 [03:46<11:28,  8.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 24/108 [03:48<09:02,  6.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 25/108 [03:54<08:39,  6.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 26/108 [04:00<08:31,  6.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 27/108 [04:12<10:35,  7.84s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 28/108 [04:18<09:46,  7.34s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 29/108 [04:30<11:19,  8.60s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 30/108 [04:41<12:20,  9.49s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▊       | 31/108 [04:53<12:57, 10.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 32/108 [04:59<11:26,  9.04s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 33/108 [05:11<12:15,  9.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███▏      | 34/108 [05:22<12:43, 10.31s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 35/108 [05:29<11:13,  9.23s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 36/108 [05:41<11:54,  9.93s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 37/108 [05:52<12:21, 10.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 38/108 [06:03<12:19, 10.56s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 39/108 [06:08<10:04,  8.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 40/108 [06:09<07:34,  6.69s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 41/108 [06:14<06:47,  6.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▉      | 42/108 [06:20<06:39,  6.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  40%|███▉      | 43/108 [06:32<08:21,  7.71s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  41%|████      | 44/108 [06:43<09:29,  8.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  42%|████▏     | 45/108 [06:45<07:11,  6.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  43%|████▎     | 46/108 [06:57<08:32,  8.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  44%|████▎     | 47/108 [07:09<09:24,  9.26s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  44%|████▍     | 48/108 [07:11<07:10,  7.18s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  45%|████▌     | 49/108 [07:23<08:23,  8.53s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  46%|████▋     | 50/108 [07:34<09:10,  9.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  47%|████▋     | 51/108 [07:46<09:39, 10.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  48%|████▊     | 52/108 [07:58<09:54, 10.62s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  49%|████▉     | 53/108 [08:09<10:01, 10.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  50%|█████     | 54/108 [08:21<10:02, 11.15s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  51%|█████     | 55/108 [08:33<09:59, 11.30s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  52%|█████▏    | 56/108 [08:44<09:53, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  53%|█████▎    | 57/108 [08:56<09:44, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  54%|█████▎    | 58/108 [09:06<09:09, 10.99s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  55%|█████▍    | 59/108 [09:18<09:08, 11.19s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  56%|█████▌    | 60/108 [09:29<09:02, 11.31s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  56%|█████▋    | 61/108 [09:35<07:39,  9.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  57%|█████▋    | 62/108 [09:39<06:02,  7.88s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  58%|█████▊    | 63/108 [09:50<06:43,  8.98s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  59%|█████▉    | 64/108 [10:02<07:11,  9.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  60%|██████    | 65/108 [10:14<07:25, 10.35s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  61%|██████    | 66/108 [10:25<07:31, 10.74s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  62%|██████▏   | 67/108 [10:28<05:37,  8.23s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  63%|██████▎   | 68/108 [10:39<06:09,  9.24s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  64%|██████▍   | 69/108 [10:47<05:43,  8.80s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  65%|██████▍   | 70/108 [10:49<04:16,  6.76s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  66%|██████▌   | 71/108 [11:01<05:03,  8.20s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  67%|██████▋   | 72/108 [11:12<05:32,  9.23s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  68%|██████▊   | 73/108 [11:24<05:47,  9.94s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  69%|██████▊   | 74/108 [11:35<05:55, 10.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  69%|██████▉   | 75/108 [11:47<05:56, 10.79s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  70%|███████   | 76/108 [11:54<05:12,  9.78s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  71%|███████▏  | 77/108 [12:06<05:20, 10.34s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  72%|███████▏  | 78/108 [12:09<04:03,  8.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  73%|███████▎  | 79/108 [12:21<04:24,  9.13s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  74%|███████▍  | 80/108 [12:32<04:35,  9.85s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  75%|███████▌  | 81/108 [12:44<04:39, 10.36s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  76%|███████▌  | 82/108 [12:55<04:38, 10.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  77%|███████▋  | 83/108 [13:07<04:34, 10.96s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  78%|███████▊  | 84/108 [13:18<04:26, 11.10s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  79%|███████▊  | 85/108 [13:24<03:36,  9.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  80%|███████▉  | 86/108 [13:25<02:36,  7.12s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  81%|████████  | 87/108 [13:34<02:40,  7.62s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  81%|████████▏ | 88/108 [13:38<02:12,  6.60s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  82%|████████▏ | 89/108 [13:50<02:34,  8.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  83%|████████▎ | 90/108 [14:02<02:44,  9.16s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  84%|████████▍ | 91/108 [14:08<02:23,  8.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  85%|████████▌ | 92/108 [14:20<02:30,  9.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  86%|████████▌ | 93/108 [14:32<02:31, 10.07s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  87%|████████▋ | 94/108 [14:43<02:28, 10.58s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  88%|████████▊ | 95/108 [14:55<02:21, 10.90s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  89%|████████▉ | 96/108 [15:07<02:13, 11.11s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  90%|████████▉ | 97/108 [15:18<02:04, 11.28s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  91%|█████████ | 98/108 [15:30<01:53, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 99/108 [15:32<01:18,  8.68s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 100/108 [15:44<01:16,  9.59s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 101/108 [15:56<01:11, 10.19s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 102/108 [16:07<01:03, 10.62s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 103/108 [16:19<00:54, 10.91s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 104/108 [16:30<00:44, 11.09s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 105/108 [16:42<00:33, 11.27s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 106/108 [16:54<00:22, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 107/108 [17:06<00:11, 11.50s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 108/108 [17:17<00:00,  9.61s/it]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Warning: Empty reference sentence detected; setting raw BERTScores to 0.

# %%
results_df = pd.DataFrame([
    {**avg_a, **bert_a},
    {**avg_b, **bert_b},
    {**avg_c, **bert_c}
], index=["Gemma", "Microsoft", "Llama"])

display(results_df)
# Out:
#              rouge1    rouge2    rougeL  bert_precision  bert_recall   bert_f1
# Gemma      0.143823  0.102429  0.125795        0.759889     0.861523  0.807231
# Microsoft  0.095097  0.069549  0.084658        0.749458     0.858103  0.799877
# Llama      0.103615  0.075338  0.092852        0.749629     0.856993  0.799505

# %%
results_df.to_csv('/content/gdrive/MyDrive/GemmaVsMicrosoftVsLlamaAllMetrics.csv', index=True)
